# %%
from IPython.core.display import Image, HTML

# %% [markdown]
# # Web Development

# %% [markdown]
# I have been experimenting with Jupyter Notebook to learn web development.

# %%
Image('./teachhtml/htmljquery_notebook.png')
