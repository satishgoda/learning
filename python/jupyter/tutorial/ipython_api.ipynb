# %% [markdown]
# * http://ipython.readthedocs.io/en/stable/api/index.html

# %%
from IPython.display import FileLink, FileLinks

# %%
FileLink('ipython_gui.ipynb')
# Out:
# F:\src\learning\python\jupyter\tutorial\ipython_gui.ipynb

# %% [markdown]
# [ipython_gui](ipython_gui.ipynb)

# %% [markdown]
# # Display
#
# * http://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html

# %%
from IPython.core import display

# %% [raw]
# %pfile display

# %% [markdown]
# ## HTML

# %% [raw]
# display.HTML?

# %%
display.HTML("""
<pre>
Hello Ipython Core
</pre>
<ol>
<li>Hello</li>
<li>IPython</li>
<li>Core</li>
</ol>
""")
# Out:
# <pre>
# Hello Ipython Core
# </pre>
# <ol>
# <li>Hello</li>
# <li>IPython</li>
# <li>Core</li>
# </ol>

# %% [markdown]
# ## Image

# %% [raw]
# display.Image?

# %%
display.Image('ipython_gui.png')
