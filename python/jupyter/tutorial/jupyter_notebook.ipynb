# %% [markdown]
# # About
#
# This Jupyter notebook demonstrates the features of the Notebook!!

# %% [markdown]
# # Shell commands

# %%
# !ls -1rt *.png
# Out:
# jupyter_notebook_login.png
# jupyter-notebook_menubar_widgets_save-with-snapshots.png
# jupyter_notebook_autocomplete_1.png
# jupyter_notebook_command_show-command_palette_1.png
# jupyter_notebook_command_show-command_palette_2.png

# %% [markdown]
# ## Tab completion
#
# * Can be accessed by pressing the TAB key (In a code cell)

# %% [markdown]
# # Loading Images

# %% [markdown]
# ## Python

# %%
from IPython.display import Image
Image("jupyter_notebook_login.png")

# %% [markdown]
# ## Loading a bunch of images from the current directory
#
# Note: The following example assumes that that [path.py](https://pypi.python.org/pypi/path.py) module is installed

# %%
from IPython.display import Image, display
import path


cwd = path.getcwdu()

cwdpath = path.Path(cwd)

for pngfile in sorted(cwdpath.listdir("*.png")):
    print(pngfile)
    display(Image(pngfile))
    print("\n\n")
# Out:
# /var/tmp/python3/notebooks/jupyter/jupyter-notebook_menubar_widgets_save-with-snapshots.png
# /var/tmp/python3/notebooks/jupyter/jupyter_notebook_autocomplete_1.png
# /var/tmp/python3/notebooks/jupyter/jupyter_notebook_command_show-command_palette_1.png
# /var/tmp/python3/notebooks/jupyter/jupyter_notebook_command_show-command_palette_2.png
# /var/tmp/python3/notebooks/jupyter/jupyter_notebook_login.png

# %% [markdown]
# ## Markdown

# %% [markdown]
# The following markdown syntax can be used to embed an image
#
# <pre>
# <b>![title](jupyter_notebook_autocomplete_1.png)</b>
# </pre>
#
# ![title](jupyter_notebook_autocomplete_1.png)

# %% [markdown]
# # References
#
# * https://guides.github.com/features/mastering-markdown/
# * http://stackoverflow.com/questions/21034373/how-to-load-edit-run-save-text-files-py-into-an-ipython-notebook-cell
# * http://stackoverflow.com/questions/32370281/how-to-include-image-or-picture-in-jupyter-notebook
